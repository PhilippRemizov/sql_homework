# %%
import sqlite3
conn2 = sqlite3.connect('task1_7.db')  
c = conn2.cursor()

# %%
request = "create table table1 (ind1 int, ind2 int, ind3 int)"
c.execute(request)
tables = c.fetchall()

# %%
# Создадим таблицу предварительно на SQL сервере (ниже решение с использованием Python psycopg2)
query = '''create table table1 as
select  cast(random()*1000 as int) as ind1, 
cast(random()*1000 as int) as ind2, 
cast(random()*1000 as int) as ind3
from generate_series(1,1000)'''

# %%
#проверка подключения PostgreSQL 
import psycopg2
import pandas as pd
#Библиотека ждя визуализации
from IPython.display import HTML
import plotly.express as px


#!введите свои реквизиты!
DB_HOST = '52.157.159.24'
DB_USER = 'student19'
DB_USER_PASSWORD = 'student19_password'
DB_NAME = 'sql_ex_for_student19'

conn = psycopg2.connect(host=DB_HOST, user=DB_USER, password=DB_USER_PASSWORD, dbname=DB_NAME)

# %%
cursor = conn.cursor()
cursor.execute(query)
conn.commit()

# %%
request = """
SELECT * from table1
"""
df = pd.read_sql_query(request, conn)

# %%
df.to_sql('table1', conn2, if_exists = 'append', index = False, index_label=None)

# %%
c.execute("SELECT * from table1")
results = c.fetchall()
data = pd.DataFrame(results)

# %%
data
# Out:
#        0    1    2
# 0    756  442  348
# 1    908  955  337
# 2     72   74  167
# 3     71  505  870
# 4    912  647  358
# ..   ...  ...  ...
# 995  405  941  509
# 996  716  204  856
# 997  431  164  894
# 998  503  822  878
# 999  831  545  428
#
# [1000 rows x 3 columns]

# %%
import plotly.graph_objects as go
import numpy as np

fig = go.Figure()
fig.add_trace(go.Histogram(histfunc="count", x=data[0].to_list(), name="ind1"))
fig.add_trace(go.Histogram(histfunc="count", x=data[1].to_list(), name="ind2"))
fig.add_trace(go.Histogram(histfunc="count", x=data[2].to_list(), name="ind3"))

# Overlay histograms
fig.update_layout(barmode='overlay')
# Reduce opacity to see both histograms
fig.update_traces(opacity=0.15)
fig.show()
# Out:
# <div>                            <div id="edeea5f0-c383-4e12-9b6e-6af37f2b938c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("edeea5f0-c383-4e12-9b6e-6af37f2b938c")) {                    Plotly.newPlot(                        "edeea5f0-c383-4e12-9b6e-6af37f2b938c",                        [{"histfunc":"count","name":"ind1","opacity":0.15,"type":"histogram","x":[756,908,72,71,912,551,294,602,570,52,307,655,992,160,29,387,232,130,119,641,9,819,584,423,767,757,764,800,857,28,232,225,916,377,679,733,91,46,200,123,868,740,396,828,195,526,208,475,455,267,554,324,396,355,624,969,148,925,99,528,239,465,429,49,700,62,867,207,128,828,434,811,700,497,30,495,416,2,727,48,231,830,169,644,610,690,854,249,800,606,196,807,906,921,901,546,919,888,658,358,816,467,119,474,27,810,317,964,751,408,981,701,399,244,879,915,43,115,380,639,499,154,413,181,380,910,318,523,412,645,577,27,461,997,110,827,958,819,376,379,235,927,154,317,658,58,431,819,339,369,550,379,10,858,101,121,828,538,775,951,711,631,740,497,902,62,807,93,740,123,623,473,602